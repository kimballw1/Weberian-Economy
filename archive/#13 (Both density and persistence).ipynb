# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler

# Load your cleaned dataset
df = pd.read_csv("/Users/kimballweeks/Downloads/cleaned_data.csv")

df = df.rename(columns={
    "pct_highschool_or_more (1990)": "pct_hs_1990",
    "Pop 2023": "pop_2023",
    "Established firms 1989": "firms_1989",
    "Established firms 2022": "firms_2022"
})

# Convert relevant columns to numeric (including from "DNE" or other junk)
df['church_persistence_index'] = pd.to_numeric(df['church_persistence_index'], errors='coerce')
df['church_density_1890'] = pd.to_numeric(df['church_density_1890'], errors='coerce')
df['income_1989_real_2023'] = pd.to_numeric(df['income_1989_real_2023'], errors='coerce')
df['pct_hs_1990'] = pd.to_numeric(df['pct_hs_1990'], errors='coerce')
df['pop_2023'] = pd.to_numeric(df['pop_2023'], errors='coerce')
df['firms_2022'] = pd.to_numeric(df['firms_2022'], errors='coerce')
df['firms_1989'] = pd.to_numeric(df['firms_1989'], errors='coerce')

# Drop rows that would break the log transforms
df = df[(df['firms_2022'] > 0) & (df['pop_2023'] > 0) & (df['firms_1989'] > 0)]

# Apply log transforms
df['log_firms_2022'] = np.log(df['firms_2022'])
df['log_firms_1989'] = np.log(df['firms_1989'])
df['log_pop_2023'] = np.log(df['pop_2023'])

# Standardize controls
scaler = StandardScaler()
df[['income_1989_scaled', 'pct_hs_1990_scaled']] = scaler.fit_transform(
    df[['income_1989_real_2023', 'pct_hs_1990']]
)

# Final dataset for regression: filter only once, now that all transforms are done
df_reg = df.dropna(subset=[
    'church_persistence_index',
    'church_density_1890',
    'income_1989_scaled',
    'pct_hs_1990_scaled',
    'log_firms_1989',
    'log_pop_2023',
    'log_firms_2022',
    'State'
])
df_reg = df_reg.replace([np.inf, -np.inf], np.nan).dropna()

# Optional: see how many rows are used
print(f"Number of observations used in regression: {len(df_reg)}")

# Run the regression
model = smf.ols(
    formula='log_firms_2022 ~ church_density_1890 + church_persistence_index + income_1989_scaled + pct_hs_1990_scaled + log_firms_1989 + log_pop_2023 + C(State)',
    data=df_reg
).fit(cov_type='HC3')

# Output the summary
print(model.summary())
# Out:
# Number of observations used in regression: 2610
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         log_firms_2022   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.964
# Method:                 Least Squares   F-statistic:                     1416.
# Date:                Thu, 09 Oct 2025   Prob (F-statistic):               0.00
# Time:                        11:29:24   Log-Likelihood:                -416.80
# No. Observations:                2610   AIC:                             939.6
# Df Residuals:                    2557   BIC:                             1251.
# Df Model:                          52
# Covariance Type:                  HC3
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -4.8593      0.163    -29.851      0.000      -5.178      -4.540
# C(State)[T.AR]               0.1033      0.051      2.031      0.042       0.004       0.203
# C(State)[T.AZ]               0.0768      0.080      0.964      0.335      -0.079       0.233
# C(State)[T.CA]               0.1845      0.049      3.751      0.000       0.088       0.281
# C(State)[T.CO]               0.5136      0.069      7.447      0.000       0.378       0.649
# C(State)[T.DE]               0.4335      0.133      3.269      0.001       0.174       0.693
# C(State)[T.FL]               0.3553      0.062      5.685      0.000       0.233       0.478
# C(State)[T.GA]               0.2065      0.048      4.334      0.000       0.113       0.300
# C(State)[T.IA]               0.0257      0.051      0.507      0.612      -0.074       0.125
# C(State)[T.ID]               0.5451      0.092      5.917      0.000       0.365       0.726
# C(State)[T.IL]              -0.0530      0.046     -1.160      0.246      -0.142       0.037
# C(State)[T.IN]              -0.0062      0.046     -0.136      0.892      -0.096       0.083
# C(State)[T.KS]               0.0754      0.055      1.378      0.168      -0.032       0.183
# C(State)[T.KY]               0.0770      0.043      1.790      0.073      -0.007       0.161
# C(State)[T.LA]               0.5288      0.066      8.066      0.000       0.400       0.657
# C(State)[T.MA]               0.2038      0.108      1.889      0.059      -0.008       0.415
# C(State)[T.MD]              -0.0144      0.070     -0.206      0.837      -0.151       0.123
# C(State)[T.ME]               0.2317      0.058      4.002      0.000       0.118       0.345
# C(State)[T.MI]               0.0929      0.051      1.805      0.071      -0.008       0.194
# C(State)[T.MN]               0.1145      0.053      2.169      0.030       0.011       0.218
# C(State)[T.MO]               0.1902      0.046      4.172      0.000       0.101       0.280
# C(State)[T.MS]               0.0632      0.051      1.236      0.216      -0.037       0.163
# C(State)[T.MT]               0.6161      0.091      6.805      0.000       0.439       0.794
# C(State)[T.NC]               0.2256      0.045      5.031      0.000       0.138       0.314
# C(State)[T.ND]               0.2683      0.083      3.239      0.001       0.106       0.431
# C(State)[T.NE]               0.0869      0.058      1.498      0.134      -0.027       0.201
# C(State)[T.NH]               0.0536      0.059      0.914      0.361      -0.061       0.169
# C(State)[T.NJ]               0.0687      0.062      1.111      0.266      -0.052       0.190
# C(State)[T.NM]               0.1219      0.118      1.036      0.300      -0.109       0.352
# C(State)[T.NV]               0.0984      0.131      0.750      0.453      -0.159       0.356
# C(State)[T.NY]              -0.0283      0.054     -0.525      0.599      -0.134       0.077
# C(State)[T.OH]              -0.1638      0.045     -3.638      0.000      -0.252      -0.076
# C(State)[T.OK]               0.2185      0.061      3.591      0.000       0.099       0.338
# C(State)[T.OR]               0.2542      0.060      4.230      0.000       0.136       0.372
# C(State)[T.PA]              -0.0019      0.042     -0.045      0.964      -0.085       0.081
# C(State)[T.RI]               0.2209      0.068      3.271      0.001       0.089       0.353
# C(State)[T.SC]               0.0919      0.058      1.572      0.116      -0.023       0.207
# C(State)[T.SD]               0.3401      0.061      5.579      0.000       0.221       0.460
# C(State)[T.TN]               0.0760      0.044      1.745      0.081      -0.009       0.161
# C(State)[T.TX]               0.2747      0.045      6.093      0.000       0.186       0.363
# C(State)[T.UT]               0.5830      0.100      5.846      0.000       0.388       0.778
# C(State)[T.VA]               0.1078      0.049      2.207      0.027       0.012       0.203
# C(State)[T.VT]               0.2781      0.068      4.061      0.000       0.144       0.412
# C(State)[T.WA]               0.2144      0.059      3.636      0.000       0.099       0.330
# C(State)[T.WI]               0.0560      0.049      1.136      0.256      -0.041       0.153
# C(State)[T.WV]              -0.0186      0.057     -0.328      0.743      -0.129       0.092
# C(State)[T.WY]               0.5138      0.170      3.021      0.003       0.180       0.847
# church_density_1890         -0.0006      0.003     -0.230      0.818      -0.006       0.005
# church_persistence_index     0.0289      0.015      1.982      0.048       0.000       0.058
# income_1989_scaled           0.0595      0.011      5.361      0.000       0.038       0.081
# pct_hs_1990_scaled           0.1339      0.017      7.905      0.000       0.101       0.167
# log_firms_1989               0.2953      0.020     15.035      0.000       0.257       0.334
# log_pop_2023                 0.7308      0.022     33.910      0.000       0.689       0.773
# ==============================================================================
# Omnibus:                      142.300   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              471.628
# Skew:                          -0.186   Prob(JB):                    3.87e-103
# Kurtosis:                       5.049   Cond. No.                         586.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)
